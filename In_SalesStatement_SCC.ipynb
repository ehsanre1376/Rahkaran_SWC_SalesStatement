# %%
import requests
import rsa
import json
import binascii
import json

G_BaseURL = "http://localhost:8585/DEV"
G_UserName = "admin"
G_PassWord = "admin"


def hex_string_to_bytes(hex_string):
    return binascii.unhexlify(hex_string)
def bytes_to_hex_string(byte_array):
    return binascii.hexlify(byte_array).decode()
def login(user_name=G_UserName, password=G_PassWord):
    url = G_BaseURL + "/Services/Framework/AuthenticationService.svc"
    session_url = url + "/session"
    login_url = url + "/login"
    response = requests.get(session_url)
    if response.status_code != 200:
        raise Exception("GET /session {}".format(response.status_code))
    session = json.loads(response.text)
    m = hex_string_to_bytes(session["rsa"]["M"])
    e = hex_string_to_bytes(session["rsa"]["E"])
    rsa_key = rsa.PublicKey(
        int.from_bytes(m, byteorder="big"), int.from_bytes(e, byteorder="big")
    )
    session_plus_password = session["id"] + "**" + password
    encrypted_password = rsa.encrypt(session_plus_password.encode(), rsa_key)
    headers = {"content-Type": "application/json"}
    data = {
        "sessionId": session["id"],
        "username": user_name,
        "password": bytes_to_hex_string(encrypted_password),
    }
    response = requests.post(login_url, headers=headers, data=json.dumps(data))
    if response.status_code != 200:
        raise Exception("POST /login {}".format(response.status_code))
    session = response.headers["Set-Cookie"].split(",")[2].split(";")[0].strip()
    return session


session = login()
print(session)
# Out:
# sg-auth-DEV=4163febe-6711-4858-b436-740af7910475

# %%
# """


def get_all_cost_centers(session):
    url = (
        G_BaseURL
        + "/General/CostCenterManagement/Services/CostCenterService.svc/GetAllCostCenters"
    )
    headers = {"Cookie": session, "content-Type": "application/json"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        raise Exception("GET /GetAllCostCenters {}".format(response.status_code))
    return response.json()


# Use the session_id and auth_cookie from the login function
#cost_centers = get_all_cost_centers(session)
#print(cost_centers)
# json_str = json.dumps(your_list)
# parsed = json.loads(cost_centers)

# Pretty print the parsed data
# print(json.dumps(parsed, indent=4))

print(
    json.dumps(
        json.loads(json.dumps(get_all_cost_centers(session))),
        indent=4,
        ensure_ascii=False,
    )
)
# """
# Out:
# [
#     {
#         "ID": 2,
#         "IsActive": true,
#         "Name": "معادن",
#         "Name_En": "",
#         "Number": "10100",
#         "Type": 2
#     },
#     {
#         "ID": 3,
#         "IsActive": true,
#         "Name": "معدن آهک",
#         "Name_En": "",
#         "Number": "10105",
#         "Type": 2
#     },
#     {
#         "ID": 4,
#         "IsActive": true,
#         "Name": "معدن گچ",
#         "Name_En": "",
#         "Number": "10110",
#         "Type": 2
#     },
#     {
#         "ID": 5,
#         "IsActive": true,
#         "Name": "دپوی کائولن",
#         "Name_En": "",
#         "Number": "10115",
#         "Type": 2
#     },
#     {
#         "ID": 6,
#         "IsActive": true,
#         "Name": "دپوی آهک",
#         "Name_En": "",
#         "Number": "10120",
#         "Type": 2
#     },
#     {
#         "ID": 7,
#         "IsActive": true,
#         "Name": "سنگ شکن آهک",
#         "Name_En": null,
#         "Number": "10125",
# ...

# %%
"""
    get all  GetRegionalDivisionList
"""



def GetRegionalDivisionList(session):
    url = (
        G_BaseURL
        + "/General/AddressManagement/Services/AddressManagementWebService.svc/GetRegionalDivisionList"
    )
    headers = {"Cookie": session, "content-Type": "application/json"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        raise Exception("GET /GetAllCostCenters {}".format(response.status_code))
    return response.json()


# Use the session_id and auth_cookie from the login function
# cost_centers = get_all_cost_centers(session)
# print(cost_centers)
# json_str = json.dumps(your_list)
# parsed = json.loads(cost_centers)

# Pretty print the parsed data
# print(json.dumps(parsed, indent=4))

print(
    json.dumps(
        json.loads(json.dumps(GetRegionalDivisionList(session))),
        indent=4,
        ensure_ascii=False,
    )
)
# """
# Out:
# [
#     {
#         "Code": "0098",
#         "Name": "ایران",
#         "ParentID": null,
#         "RegionalDivisionID": 1,
#         "Type": 1
#     },
#     {
#         "Code": "021",
#         "Name": "استان تهران",
#         "ParentID": 1,
#         "RegionalDivisionID": 2,
#         "Type": 2
#     },
#     {
#         "Code": "021",
#         "Name": "شهرستان تهران",
#         "ParentID": 2,
#         "RegionalDivisionID": 3,
#         "Type": 3
#     },
#     {
#         "Code": "021",
#         "Name": "شهرستان شمیرانات",
#         "ParentID": 2,
#         "RegionalDivisionID": 4,
#         "Type": 3
#     },
#     {
#         "Code": "031",
#         "Name": "استان اصفهان",
#         "ParentID": 1,
#         "RegionalDivisionID": 5,
#         "Type": 2
#     },
#     {
#         "Code": null,
#         "Name": "استان فارس",
#         "ParentID": 1,
#         "RegionalDivisionID": 6,
#         "Type": 2
#     },
#     {
#         "Code": "071",
# ...

# %%
# """


def ERA_Update(session, data):
    url = G_BaseURL + "/System/BusinessRuleEngine/Service.svc/call"
    headers = {"Cookie": session, "content-Type": "application/json"}
    JsonData = {"Name": "SalesStatement", "Parameters": json.dumps(data)}
    response = requests.post(url, headers=headers, data=json.dumps(JsonData))
    if response.status_code != 200:
        raise Exception("GET /GetAllCostCenters {}".format(response.status_code))
    return response.json()

"""
# Use the session_id and auth_cookie from the login function
ERA = ERA_Update(
    session, {"InText": "ذزفکا", "InText1": "بر", "InValue": 1, "OutBoolean": "None"}
)
print(ERA)
"""
# """


In_SalesStatement1 = {
    "ID": "-1",
    "Number": None,
    "State": "1",
    "CustomerRef": "200080008281",
    "Price": "1000000000",
    "AdditionAmount": "0",
    "ReductionAmount": "0",
    "NetPrice": "1000000000",
    "CurrencyRef": "1",
    "Date": "05/11/2024 00:00:00",
    "SalesOfficeRef": "2",
    "CompanyRef": "1",
    "SalesAreaRef": "2",
    "RecipientType": "4",
    "RecipientRef": "240000004",
    "SellerBrokerRef": "1",
    "CustomerBrokerRef": "1",
    "DeliveryAddressRef": "200080009604",
    "DeliveryAddressType": "1",
    "StatementType": "1",
    "DeliverySpace": "08/08/2024 00:00:00",
    "ContractNo": "123654",
    "ContractDate": None,
    "Creator": "280011461",
    "CreationDate": "04/07/2025 14:38:01",
    "LastModifier": "280011461",
    "LastModificationDate": "04/07/2024 14:55:20",
    "PlantRef": "1",
    "CalculationDate": "05/11/2024 23:59:00",
    "EffectiveNetPrice": "1000000000",
    "BrokerWageNetAmount": "2550000",
    "HiddenPayerAccountRef": "4981",
    "HasCommissionVoucher": False,
    "ReferenceType": "0",
    "ReferenceRef": None,
    "RecipientPartyRef": "240001224",
    "BranchRef": "1",
    "FiscalYearRef": "102",
    "SalesTypeRef": "1",
    "PaymentAgreementRef": "1",
    "InventoryRef": "24",
    "OperationalCurrencyExchangeRateRef": None,
    "Description": None,
    "PrePaidAmount": "0",
    "IncludedPolicies": None,
    "ExcludedPolicies": "21,31,41,51,61,71,81,91",
    "IsImported": False,
    "ShippingPointRef": None,
    "ReleaseDate": None,
    "SettlementDate": None,
    "AllocationDate": None,
    "DetailNumber": "",
    "Producer": "",
    "SupplierCode": "",
    "DeliveryPlace": "",
    "ContractID": "",
    "OperationalCurrencyExchangeRate": "1",
    "OperationalCurrencyExchangeRateIsReversed": False,
    "WithoutUndertaker": None,
    "Sys__EntityModificationState": "Modified",
    "event__userId": None,
    "sys__entityCode": None,
    "sys__ActivityUniqueID": None,
    "sys__InstanceID": None,
    "sys__TaskID": None,
    "event__sourceState": None,
    "event__targetState": None,
    "SalesStatementWageResults": [
        {
            "ID": "-1",
            "SalesStatementRef": "12505",
            "BrokerServiceRef": "1",
            "CutsAndCostsRef": None,
            "CalculationPrecedence": "0",
            "CurrencyRef": "1",
            "Value": "690000",
            "ValueSetByUser": True,
            "Sys__EntityModificationState": "New",
            "event__userId": None,
            "sys__entityCode": None,
            "sys__ActivityUniqueID": None,
            "sys__InstanceID": None,
            "sys__TaskID": None,
            "sys_SerializeUID": "321ce38c-edf3-438c-81b3-810b8534e41c",
        },
        {
            "ID": "-2",
            "SalesStatementRef": "12505",
            "BrokerServiceRef": "4",
            "CutsAndCostsRef": None,
            "CalculationPrecedence": "0",
            "CurrencyRef": "1",
            "Value": "620000",
            "ValueSetByUser": True,
            "Sys__EntityModificationState": "New",
            "event__userId": None,
            "sys__entityCode": None,
            "sys__ActivityUniqueID": None,
            "sys__InstanceID": None,
            "sys__TaskID": None,
            "sys_SerializeUID": "913ff373-3666-40d5-97e2-6ce59638b714",
        },
        {
            "ID": "-3",
            "SalesStatementRef": "12505",
            "BrokerServiceRef": "5",
            "CutsAndCostsRef": None,
            "CalculationPrecedence": "0",
            "CurrencyRef": "1",
            "Value": "2621200",
            "ValueSetByUser": True,
            "Sys__EntityModificationState": "New",
            "event__userId": None,
            "sys__entityCode": None,
            "sys__ActivityUniqueID": None,
            "sys__InstanceID": None,
            "sys__TaskID": None,
            "sys_SerializeUID": "747bb9e3-4ea7-4fb5-a201-d33b00b3b122",
        },
    ],
    "SalesStatementWageResults.isLoaded": True,
    "SalesStatementPolicyResults": [
        {
            "ID": "-1",
            "SalesStatementRef": "12505",
            "BusinessPolicyRef": "64",
            "BusinessPolicyConditionRef": "58",
            "BusinessPolicyConditionRowRef": "88",
            "Price": None,
            "Value": '\u003cBPCR TD="12505" HI="0" CSR="0" IF="0" IA="1" SDI="8921"\u003e\r\n  \u003cPCI ID="64" CP="0" SPT="Other" /\u003e\r\n  \u003cCRC ID="58" RI="88" /\u003e\r\n  \u003cCRV CCV="0" VC="0" T="L" D="ادامه عملیات"\u003e\r\n    \u003cLV T="MessageType" C="3" /\u003e\r\n  \u003c/CRV\u003e\r\n  \u003cED /\u003e\r\n\u003c/BPCR\u003e',
            "Sys__EntityModificationState": "Modified",
            "event__userId": None,
            "sys__entityCode": None,
            "sys__ActivityUniqueID": None,
            "sys__InstanceID": None,
            "sys__TaskID": None,
            "sys_SerializeUID": "f1c41f0d-d27b-43b1-ae60-9c04664692e5",
        }
    ],
    "SalesStatementPolicyResults.isLoaded": True,
    "SalesStatementItems": [
        {
            "ID": None,
            "DocumentRef": None,
            "SalesStatementNumber": "14702359",
            "SalesStatementDate": "05/11/2024 00:00:00",
            "RowNumber": "1",
            "State": "1",
            "ProductRef": "7",
            "ProductUnitRef": "37",
            "Quantity": "100000",
            "MajorUnitQuantity": "100000",
            "InitialQuantity": "100000",
            "Fee": "10000",
            "Price": "1000000000",
            "AdditionAmount": "0",
            "ReductionAmount": "0",
            "NetPrice": "1000000000",
            "EffectiveNetPrice": "1000000000",
            "SalesAreaRef": "2",
            "Description": "852",
            "FreeProductBusinessPolicyRef": None,
            "ParentRef": None,
            "Type": "1",
            "HasReservation": False,
            "IncludedPolicies": None,
            "ExcludedPolicies": None,
            "FreeProductBusinessPolicyConditionRowRef": None,
            "TrackingFactor1": None,
            "TrackingFactor2": None,
            "TrackingFactor3": None,
            "TrackingFactor4": None,
            "TrackingFactor5": None,
            "PartTrackingFactorRef1": None,
            "PartTrackingFactorRef2": None,
            "PartTrackingFactorRef3": None,
            "PartTrackingFactorRef4": None,
            "PartTrackingFactorRef5": None,
            "TrackingFactorValue": None,
            "TrackingFactorInputMode1": None,
            "TrackingFactorInputMode2": None,
            "TrackingFactorInputMode3": None,
            "TrackingFactorInputMode4": None,
            "TrackingFactorInputMode5": None,
            "PriceBaseUnitRef": "37",
            "PriceBaseFee": "10000",
            "InclusiveRelatedInitialQuantity": None,
            "InclusiveRelatedInitialUnit": None,
            "OriginalFreeProductRef": None,
            "BatchRef": None,
            "Sys__EntityModificationState": "Original",
            "event__userId": None,
            "sys__entityCode": None,
            "sys__ActivityUniqueID": None,
            "sys__InstanceID": None,
            "sys__TaskID": None,
            "event__sourceState": None,
            "event__targetState": None,
            "SalesStatementItemPolicyResults": None,
            "FreeProductItems": None,
            "sys_SerializeUID": "3292ff92-51bc-4943-831f-9fd590703a8f",
        }
    ]

}
data = {"In_SalesStatement": In_SalesStatement1}

ERA = ERA_Update(
    session, data
)
print(ERA)
# Out:
# {"OutId_SalesStatement":12544,"Out_ErrorText":""}
